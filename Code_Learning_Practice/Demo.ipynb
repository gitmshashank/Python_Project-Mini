# %% [markdown]
# # This is my First interaction with PYTHON

# %% [markdown]
# # MODULE-1

# %% [markdown]
# ## About Number and Data Set

# %%
type(11)
# Out:
# int

# %%
type(11.11)
# Out:
# float

# %%
type("Hello World")
# Out:
# str

# %%
type("Hello World 101")
# Out:
# str

# %%
type(-7)
# Out:
# int

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %% [markdown]
# ## Converting the Data Set

# %%
int(3.14)
# Out:
# 3

# %%
float(3)
# Out:
# 3.0

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
bool(1)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %% [markdown]
# ## Expressions and Variables

# %%
11/2
# Out:
# 5.5

# %%
11//2
# Out:
# 5

# %%
(30+2)*60
# Out:
# 1920

# %%
b=25

# %%
b**2
# Out:
# 625

# %% [markdown]
# ## Variables

# %%
x=10

# %%
y=20

# %%
x+y
# Out:
# 30

# %%
(x+y)*10
# Out:
# 300

# %%
x-y
# Out:
# -10

# %%
(x+y)*(x-y)
# Out:
# -300

# %%
total_min=43+42+58

# %%
total_hr=total_min/60

# %%
print(total_hr)
# Out:
# 2.3833333333333333

# %%
int(total_hr)
# Out:
# 2

# %%
x=7

# %%
B=20

# %%
B**2
# Out:
# 400

# %%
y=20

# %%
(x+y)
# Out:
# 27

# %% [markdown]
# ## Strings

# %%
Name= "Shashank Mishra"

# %%
Name[0]
# Out:
# 'S'

# %% [markdown]
# ### positive indexing

# %%
Name[10]
# Out:
# 'i'

# %% [markdown]
# ### Nagative Indexing

# %%
Name[-10]
# Out:
# 'a'

# %% [markdown]
# ### Binding the integers

# %%
Name[0:4]
# Out:
# 'Shas'

# %%
Name[8:12]
# Out:
# ' Mis'

# %% [markdown]
# ### Strides

# %%
Name[::2]
# Out:
# 'Sahn iha'

# %%
Name[::3]
# Out:
# 'SsnMh'

# %% [markdown]
# ### Length of Strings

# %%
len(Name)
# Out:
# 15

# %% [markdown]
# ### Concatenate Strings

# %%
Name+" is the best"
# Out:
# 'Shashank Mishra is the best'

# %%
Name+" is an MBA Student"
# Out:
# 'Shashank Mishra is an MBA Student'

# %%
3 * Name
# Out:
# 'Shashank MishraShashank MishraShashank Mishra'

# %% [markdown]
# ## Escape Sequences

# %% [markdown]
# ### \n Nest Line

# %%
print(" Hello \n World")
# Out:
#  Hello
#  World

# %% [markdown]
# ### \t Tab

# %%
print(" hello \t World")
# Out:
#  hello 	 World

# %% [markdown]
# ## STRING METHODS

# %%
A= "shashank mishra"

# %%
B= A.upper()

# %%
print(B)
# Out:
# SHASHANK MISHRA

# %%
C= B.lower()

# %%
print(C)
# Out:
# shashank mishra

# %%
x="SHASHANK MISHRA"

# %%
y=x.replace("MISHRA","Mishra ji")

# %%
print(y)
# Out:
# SHASHANK Mishra ji

# %%
x.find("SH")
# Out:
# 0

# %% [markdown]
# ## Output value will be -1 when the sub string is not present in the string

# %%
x.find("&")
# Out:
# -1

# %% [markdown]
# # Module-2

# %% [markdown]
# ## List and Tuples

# %% [markdown]
# ### Tuples

# %%
List=("Lucy",10,21.22)

# %%
type(List)
# Out:
# tuple

# %%
List[1]
# Out:
# 10

# %%
List[0]
# Out:
# 'Lucy'

# %%
List[2]
# Out:
# 21.22

# %%
List[-1]
# Out:
# 21.22

# %%
List[-2]
# Out:
# 10

# %%
List[-3]
# Out:
# 'Lucy'

# %%
List2=List +("John",22)

# %%
print(List2)
# Out:
# ('Lucy', 10, 21.22, 'John', 22)

# %%
List2[0:3]
# Out:
# ('Lucy', 10, 21.22)

# %%
len(List2)
# Out:
# 5

# %%
###Tuples are Immutable

# %%
List_Numbers=(10,22,13,4,0,30)

# %%
sorted(List_Numbers)
# Out:
# [0, 4, 10, 13, 22, 30]

# %% [markdown]
# #### Nesting in Tuples (Tuples as a TREE)

# %%
NT=(1,2, ("pop", "rock"),(3,4),("cafe",11,22))

# %%
NT[1]
# Out:
# 2

# %%
NT[0]
# Out:
# 1

# %%
NT[2]
# Out:
# ('pop', 'rock')

# %%
NT[3]
# Out:
# (3, 4)

# %%
NT[4]
# Out:
# ('cafe', 11, 22)

# %%
NT[2][1]
# Out:
# 'rock'

# %%
NT[4][0]
# Out:
# 'cafe'

# %% [markdown]
# ## Lists

# %% [markdown]
# ### Nesting in Lists

# %%
Lists=[26,10.1,1982,[1,2],("X","Y",22)]

# %% [markdown]
# ### Indexing

# %%
Lists[3]
# Out:
# [1, 2]

# %%
Lists[4][0]
# Out:
# 'X'

# %%
Lists[-1][0]
# Out:
# 'X'

# %% [markdown]
# ### Slicing

# %%
Lists[3:5]
# Out:
# [[1, 2], ('X', 'Y', 22)]

# %% [markdown]
# ### Lists are Mutuable

# %% [markdown]
# #### Concatenating LISTS

# %%
Classroom=["Riya",22,"Roshan",33]

# %%
Classroom.extend(["Hari",20])

# %%
print(Classroom)
# Out:
# ['Riya', 22, 'Roshan', 33, 'Hari', 20]

# %%
Classroom.append(["Ricky",66])

# %%
print(Classroom)
# Out:
# ['Riya', 22, 'Roshan', 33, 'Hari', 20, ['Ricky', 66]]

# %%
Classroom[0]
# Out:
# 'Riya'

# %%
Classroom[0]="Gini"

# %%
print(Classroom)
# Out:
# ['Gini', 22, 'Roshan', 33, 'Hari', 20, ['Ricky', 66]]

# %% [markdown]
# #### Deleting from LISTS

# %%
Classroom[6]
# Out:
# ['Ricky', 66]

# %%
del(Classroom[6])

# %%
print(Classroom)
# Out:
# ['Gini', 22, 'Roshan', 33, 'Hari', 20]

# %% [markdown]
# #### Spliting from LISTS

# %%
SHOP=["X,Y,Z,A,B"]

# %%
SHOP[0].split(",")
# Out:
# ['X', 'Y', 'Z', 'A', 'B']

# %% [markdown]
# #### Alising

# %%
Business= ["Gaming","Travel",22]

# %%
SHOP = Business

# %%
print(SHOP)
# Out:
# ['Gaming', 'Travel', 22]

# %% [markdown]
# #### CLONING

# %%
SHOP=Business[:]

# %%
SHOP[0]="Clubbing"

# %%
print(Business)
# Out:
# ['Gaming', 'Travel', 22]

# %%
print(SHOP)
# Out:
# ['Clubbing', 'Travel', 22]

# %%
help(SHOP)
# Out:
# Help on list object:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return bool(key in self).
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(self, index, /)
#  |      Return self[index].
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
# ...

# %% [markdown]
# ## Dictionaries

# %%
my_dict={
    "name": "John",
    "age":20,
    "city":"London"
}

# %%
print(my_dict["name"])
# Out:
# John

# %%
print(my_dict.get("city"))
# Out:
# London

# %%
my_dict["country"]="UK"

# %%
my_dict['age']=29

# %%
print(my_dict)
# Out:
# {'name': 'John', 'age': 29, 'city': 'London', 'country': 'UK'}

# %%
my_dict.pop("age")
# Out:
# 29

# %%
print(my_dict)
# Out:
# {'name': 'John', 'city': 'London', 'country': 'UK'}

# %%
for key in my_dict: print(key)
# Out:
# name
# city
# country

# %%
for value in my_dict.values():print(value)
# Out:
# John
# London
# UK

# %%
my_dict.values:print(value)
# Out:
# UK

# %%
"name"in my_dict
# Out:
# True

# %%
my_dict.keys()
# Out:
# dict_keys(['name', 'city', 'country'])

# %%
my_dict.values()
# Out:
# dict_values(['John', 'London', 'UK'])

# %% [markdown]
# ## SETS

# %%
album_list=["Michael Jackson", "Thriller","Thriller",1982]

# %%
album_set=set(album_list)

# %%
print(album_set)
# Out:
# {'Michael Jackson', 'Thriller', 1982}

# %%
album_set.add("Jordan")

# %%
print(album_set)
# Out:
# {'Jordan', 'Michael Jackson', 'Thriller', 1982}

# %%
album_set.remove(1982)

# %%
print(album_set)
# Out:
# {'Jordan', 'Michael Jackson', 'Thriller'}

# %%
"Thriller"in album_set
# Out:
# True

# %%
album_set_1={"Back in Black", "AC/DC"}

# %%
album_set_2={"The Dark Side of the Moon","Back in Black", "AC/DC"}

# %%
album_set_3=album_set_1&album_set_2

# %%
print(album_set_3)
# Out:
# {'AC/DC', 'Back in Black'}

# %%
album_set_1.issubset(album_set_2)
# Out:
# True

# %% [markdown]
# # MODULE-3

# %% [markdown]
# ## Conditions and Branching

# %% [markdown]
# ### Comparison Operators

# %%
a=6

# %%
a==7
# Out:
# False

# %%
a==6
# Out:
# True

# %%
i=6

# %%
if i>5:
    print("i is greater than 5")
else:
    print("i is not greater than 5")
# Out:
# i is greater than 5

# %%
i!=6
# Out:
# False

# %%
age=23

# %%
if(age>=18):
    print("you can enter")
else:
    print("move on")
# Out:
# you can enter

# %%
if (age>21):
    print("you can enter")
elif (age==18):
    print("go see Pink Floyd")
else:
    print("go see meat loaf")
# Out:
# you can enter

# %%
album_year=2001

# %%
if(album_year<1980)or(album_year>1989):
    print("The album was made in 70's or 90's")
else:
    print("The Album was made in the 1980's")
# Out:
# The album was made in 70's or 90's

# %%
if(album_year>1979)and(album_year<1990):
    print("The album was made in 70's or 90's")
else:
    print("The Album was made in the 1980's")
# Out:
# The Album was made in the 1980's

# %% [markdown]
# ## LOOPS

# %%
squares=["red","yellow","green","purple","blue"]
for squares in squares:
    squares

# %%
for x in range(0,3):
    print(x)
# Out:
# 0
# 1
# 2

# %%
for x in ['A', 'B','C']:
    print(x+'A')
# Out:
# AA
# BA
# CA

# %% [markdown]
# ## Functions

# %%
len([0,0,1])
# Out:
# 3

# %%
len([sum([0,0,1])])
# Out:
# 1

# %%
L=[1,3,2]
sorted(L)
# Out:
# [1, 2, 3]

# %%
L=[1,3,2]
L.sort()

# %%
print(L)
# Out:
# [1, 2, 3]

# %% [markdown]
# #### Define a Function

# %%
def add1(a):
    b=a+1
    return b

# %%
add1(10)
# Out:
# 11

# %%
def square1(a):
    b=a*a
    return b

# %%
square1(10)
# Out:
# 100

# %%
c=add1(2)
c=add1(10)

# %%
"""
add 1 to a
"""
# Out:
# '\nadd 1 to a\n'

# %%
def Mult(a,b):
    c=a*b
    return c

# %%
Mult(2,3)
# Out:
# 6

# %%
def sqroot(x):
    y=(x)^(0.5)
    return y

# %%
sqroot(25)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[842], line 1
# ----> 1 sqroot(25)
#
# Cell In[840], line 2, in sqroot(x)
#       1 def sqroot(x):
# ----> 2     y=(x)^(0.5)
#       3     return y
#
# TypeError: unsupported operand type(s) for ^: 'int' and 'float'

# %%
import math
def calculate_square_root(number):
    if number<0:
        return"square root is not defined for negative numbers."
    return math.sqrt(number)

# %%
result=calculate_square_root(100)

# %%
print(result)
# Out:
# 10.0

# %% [markdown]
# ## Exception Handeling

# %%
"""
doubt
"""
# Out:
# '\ndoubt\n'

# %% [markdown]
# ## Objects and Classes

# %% [markdown]
# # MODULE 4

# %% [markdown]
# ## Reading files with Open

# %%
File1=open("/resources/data/excample2.txt","r")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[866], line 1
# ----> 1 File1=open("/resources/data/excample2.txt","r")
#
# File /opt/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/resources/data/excample2.txt'

# %%
"""
r= reading, w= writing, a=appending
"""
# Out:
# '\nr= reading, w= writing, a=appending\n'

# %%
"""
using with statement is a better practice as it automatically closes the file.
"""
# Out:
# '\nusing with statement is a better practice as it automatically closes the file.\n'

# %%
with open("example1.txt","r") as File1:
    file_stuff=File1.read()
    print(file_stuff)
print(File1.closed)
print(file_stuff)

# %% [markdown]
# ## Pandas

# %% [markdown]
# ## Numpy in Python
