# %%
attendence = ["Sandeep Kumar", 124,True,
              "Singh Niteshkumar Mithelesh", 245 , True,
              "Pooja", 0, False]

attendence.append("Anant")
print(attendence)
attendence.insert(3, "New Value")
attendence
mylist = [1,2,3,6,4,5,3,1,2]

mylist.remove(2)
mylist
mylist.remove(1)
mylist

# %%
mylist = [1,2,6,5,3,1,2]

# %%
mylist.sort()
mylist
# Out:
# [1, 1, 2, 2, 3, 5, 6]

# %% [markdown]
# Sets

# %%
myset = set()

# %%
myset
# Out:
# set()

# %%
myset.add(123)
myset
# Out:
# {123}

# %%
myset.union
myset
# Out:
# {123}

# %%
set1 = {1,2,3}
set2 = {3,4,5}

# %%
new_set = set1.union(set2)
new_set
# Out:
# {1, 2, 3, 4, 5}

# %%
set2.difference(set1)
# Out:
# {4, 5}

# %%
my_dict= {
    "Name": 'Sandeep Kumar',
    "Roll Number" : 124,
    "Attendence" : True
}

# %%
my_dict["Name"]
# Out:
# 'Sandeep Kumar'

# %%
my_dict["Attendence"]
# Out:
# True

# %%
my_dict2= {
    "Name": 'Sandeep Kumar',
    "Roll Number" : 124,
    "Attendence" : True
}

# %%
del my_dict["Roll Number"]

# %%
my_dict
# Out:
# {'Name': 'Sandeep Kumar', 'Attendence': True}
